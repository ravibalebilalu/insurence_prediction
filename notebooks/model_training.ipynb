# %%
import pandas as pd 
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.compose import ColumnTransformer

from sklearn.model_selection import train_test_split,GridSearchCV

from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
 
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("data/insurance.csv")
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
df["loc_y"] =  df["region"].apply(lambda x: x[:5])
df["loc_x"] =  df["region"].apply(lambda x: x[5:])
df.drop(columns="region",inplace=True)

# %%
def chop_outliers(data):
    q1,q3 = np.percentile(data,[25,75])
    iqr = q3 - q1
    lower_fence = q1 -  (1.5 * iqr)
    higher_fence = q3 + (1.5 * iqr)
    return np.clip(data,lower_fence,higher_fence)

# %%
#for col in df.select_dtypes(exclude="object"):
#    df[col] = chop_outliers(df[col])

# %%
x = df.drop(columns="expenses")
y = df["expenses"]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=42)
cats = x_train.select_dtypes("object").columns
nums = x_train.select_dtypes(exclude="object").columns
x_train
# Out:
#       age     sex   bmi  children smoker  loc_y loc_x
# 560    46  female  20.0         2     no  north  west
# 1285   47  female  24.3         0     no  north  east
# 1142   52  female  24.9         0     no  south  east
# 969    39  female  34.3         5     no  south  east
# 486    54  female  21.5         3     no  north  west
# ...   ...     ...   ...       ...    ...    ...   ...
# 1095   18  female  31.4         4     no  north  east
# 1130   39  female  23.9         5     no  south  east
# 1294   58    male  25.2         0     no  north  east
# 860    37  female  47.6         2    yes  south  west
# 1126   55    male  29.9         0     no  south  west
#
# [1070 rows x 7 columns]

# %%
cat_pipe = Pipeline(
    steps=[
        ("imputer",SimpleImputer(strategy="most_frequent")),
        ("encoder",OneHotEncoder(handle_unknown="ignore",sparse_output=False)),
        ("scaler",StandardScaler())
    ]
)

nums_pipe =  Pipeline(
    steps=(
        [
            ("imputer",SimpleImputer(strategy="mean")),
            ("scaler",StandardScaler())
        ]
    )
)
preprocessor = ColumnTransformer(
   [ ("num",nums_pipe,nums),
    ("cat",cat_pipe,cats)]
)

# %%
x_train = preprocessor.fit_transform(x_train)
x_test = preprocessor.transform(x_test)

# %%
models = {

                "linear-regression":LinearRegression(),
                "ridge-regression":Ridge(),
                "lasso-regression":Lasso(),
                "Knn-regression":KNeighborsRegressor(),
                "Decision-tree-regressor":DecisionTreeRegressor(random_state=42),
                "Random-forest-regressor":RandomForestRegressor(random_state=42),
                "AdaBoostRegressor":AdaBoostRegressor(random_state=42),
                "GradientBoostingRegressor":GradientBoostingRegressor(random_state=42)

            }
def check_models(models):
    for name,c_model in models.items():
        model = c_model
        model.fit(x_train,y_train)
        print(F"model : {name}")
        print(f"Traing score :{model.score(x_train,y_train)}")
        print(f"Testing score :{model.score(x_test,y_test)}")
        print("....................")
check_models(models)
# Out:
# model : linear-regression
# Traing score :0.741730377656061
# Testing score :0.7833716676182348
# ....................
# model : ridge-regression
# Traing score :0.7417301298751189
# Testing score :0.7833464886351187
# ....................
# model : lasso-regression
# Traing score :0.741730326632524
# Testing score :0.7833544529942493
# ....................
# model : Knn-regression
# Traing score :0.8605167058229277
# Testing score :0.7994894270006581
# ....................
# model : Decision-tree-regressor
# Traing score :0.9983078115527046
# Testing score :0.7371613778220228
# ....................
# model : Random-forest-regressor
# Traing score :0.9747689709826177
# Testing score :0.8595135140369119
# ....................
# model : AdaBoostRegressor
# Traing score :0.8143552509215202
# Testing score :0.8164154963307407
# ....................
# model : GradientBoostingRegressor
# Traing score :0.8973451532390757
# Testing score :0.8790886533461493
# ....................

# %%
params={    
                          "linear-regression":{},
                          "ridge-regression":{
                            'alpha':[.1,.01,0.5,.001],
                            'solver':['auto','svd','cholesky','lsqr','sag','saga'],
                            'max_iter':[100,200,300,400,500]
                          },
                          "lasso-regression":{
                            'alpha':[.1,.01,0.5,.001],
                            
                            'max_iter':[100,200,300,400,500]
                          },
                          "Knn-regression":{
                            'n_neighbors':[3,5,7,9,11],
                            'weights':['uniform','distance'],
                            'algorithm':['auto','ball_tree','kd_tree','brute'],
                            'leaf_size':[10,20,30,40,50]
                          },

                        "Decision-tree-regressor": {
                            'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
                            'splitter':['best','random'],
                             'max_features':['sqrt','log2'],
                        },
                        "Random-forest-regressor":{
                             'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],

                            'max_features':['sqrt','log2',None],
                            'n_estimators': [8,16,32,64,128,256]
                        },

                        "AdaBoostRegressor":{
                            'learning_rate':[.1,.01,0.5,.001],
                             'loss':['linear','square','exponential'],
                            'n_estimators': [8,16,32,64,128,256]
                        },

                        "GradientBoostingRegressor":{
                             'loss':['squared_error', 'huber', 'absolute_error', 'quantile'],
                            'learning_rate':[.1,.01,.05,.001],
                            'subsample':[0.6,0.7,0.75,0.8,0.85,0.9],
                             'criterion':['squared_error', 'friedman_mse'],
                             'max_features':['auto','sqrt','log2'],
                            'n_estimators': [8,16,32,64,128,256]
                        }
                      
                    }
def evaluate_models(x_train,y_train,x_test,y_test,models,params):

    
    train_report ,test_report= {},{}
    for name,algo in models.items():
        model = algo
        param = params[name]
        grid_search = GridSearchCV(model,param,cv=3,n_jobs=-1,verbose=2)
        grid_search.fit(x_train,y_train)
        model.set_params(**grid_search.best_params_)
        
        model.fit(x_train,y_train)
        y_train_pred = model.predict(x_train)
        y_test_pred = model.predict(x_test)
        train_model_score = r2_score(y_train,y_train_pred)
        test_model_score = r2_score(y_test,y_test_pred)
        
        train_report[name] = train_model_score
        test_report[name] = test_model_score
    return [train_report,test_report]

train_report,test_report = evaluate_models(x_train,y_train,x_test,y_test,models,params)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# [CV] END .................................................... total time=   0.0s
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# [CV] END ...............alpha=0.1, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=100, solver=saga; total time=   0.0s[CV] END ...............alpha=0.1, max_iter=100, solver=saga; total time=   0.0s
#
# [CV] END ...............alpha=0.1, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=svd; total time=   0.0s[CV] END ...........alpha=0.1, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=200, solver=sag; total time=   0.0s
#
# [CV] END ...............alpha=0.1, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=auto; total time=   0.0s[CV] END ...........alpha=0.1, max_iter=400, solver=cholesky; total time=   0.0s
#
# [CV] END ...........alpha=0.1, max_iter=400, solver=cholesky; total time=   0.0s[CV] END ...............alpha=0.1, max_iter=500, solver=auto; total time=   0.0s
#
# [CV] END ...............alpha=0.1, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.1, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.1, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.1, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=saga; total time=   0.0s[CV] END ...............alpha=0.01, max_iter=400, solver=sag; total time=   0.0s
#
# [CV] END ..............alpha=0.01, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=200, solver=saga; total time=   0.0s[CV] END ..............alpha=0.01, max_iter=400, solver=auto; total time=   0.0s
#
# [CV] END ..............alpha=0.01, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=400, solver=svd; total time=   0.0s[CV] END ..............alpha=0.01, max_iter=400, solver=saga; total time=   0.0s
#
# [CV] END ..............alpha=0.01, max_iter=500, solver=auto; total time=   0.0s[CV] END ..............alpha=0.01, max_iter=300, solver=auto; total time=   0.0s[CV] END ...............alpha=0.01, max_iter=400, solver=svd; total time=   0.0s
#
#
# [CV] END ...............alpha=0.01, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=100, solver=lsqr; total time=   0.0s[CV] END ...............alpha=0.01, max_iter=500, solver=svd; total time=   0.0s
#
# [CV] END ..............alpha=0.01, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ..........alpha=0.01, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.01, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=100, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.01, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=100, solver=sag; total time=   0.0s[CV] END ..............alpha=0.01, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=200, solver=svd; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=100, solver=auto; total time=   0.0s[CV] END ................alpha=0.5, max_iter=200, solver=svd; total time=   0.0s
#
# [CV] END ................alpha=0.5, max_iter=300, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=300, solver=svd; total time=   0.0s[CV] END ................alpha=0.5, max_iter=100, solver=sag; total time=   0.0s
#
# [CV] END ................alpha=0.5, max_iter=300, solver=svd; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=100, solver=auto; total time=   0.0s
#
# [CV] END ...........alpha=0.5, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=100, solver=auto; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=100, solver=saga; total time=   0.0s
#
# [CV] END ...........alpha=0.5, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=200, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=saga; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=lsqr; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=lsqr; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=lsqr; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=300, solver=sag; total time=   0.0s[CV] END ................alpha=0.5, max_iter=400, solver=svd; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=saga; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=400, solver=cholesky; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=500, solver=auto; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=200, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ...........alpha=0.5, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=saga; total time=   0.0s[CV] END ...............alpha=0.5, max_iter=500, solver=lsqr; total time=   0.0s
#
# [CV] END ...............alpha=0.5, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ................alpha=0.5, max_iter=500, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=500, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=100, solver=svd; total time=   0.0s
# [CV] END ...............alpha=0.5, max_iter=500, solver=saga; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=100, solver=cholesky; total time=   0.0s[CV] END ..............alpha=0.001, max_iter=100, solver=svd; total time=   0.0s
#
# [CV] END .........alpha=0.001, max_iter=100, solver=cholesky; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=100, solver=cholesky; total time=   0.0s[CV] END .............alpha=0.001, max_iter=100, solver=lsqr; total time=   0.0s
#
# [CV] END .............alpha=0.001, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=100, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=100, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=saga; total time=   0.0s[CV] END ..............alpha=0.001, max_iter=100, solver=sag; total time=   0.0s
#
# [CV] END .............alpha=0.001, max_iter=200, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=100, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=svd; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=svd; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=200, solver=cholesky; total time=   0.0s[CV] END .........alpha=0.001, max_iter=200, solver=cholesky; total time=   0.0s
#
# [CV] END .............alpha=0.001, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=lsqr; total time=   0.0s[CV] END .........alpha=0.001, max_iter=200, solver=cholesky; total time=   0.0s
#
# [CV] END .............alpha=0.001, max_iter=200, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=200, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=200, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=300, solver=svd; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=300, solver=cholesky; total time=   0.0s[CV] END ..............alpha=0.001, max_iter=300, solver=svd; total time=   0.0s
#
# [CV] END .........alpha=0.001, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=300, solver=svd; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=300, solver=cholesky; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=300, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=300, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=300, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=300, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=svd; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=400, solver=cholesky; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=lsqr; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=400, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=auto; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=auto; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=svd; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=svd; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=400, solver=saga; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END .........alpha=0.001, max_iter=500, solver=cholesky; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=svd; total time=   0.0s[CV] END .........alpha=0.001, max_iter=500, solver=cholesky; total time=   0.0s
#
# [CV] END .............alpha=0.001, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=lsqr; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=sag; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=sag; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=saga; total time=   0.0s
# [CV] END .............alpha=0.001, max_iter=500, solver=saga; total time=   0.0s
# [CV] END ..............alpha=0.001, max_iter=500, solver=sag; total time=   0.0s
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] END ............................alpha=0.1, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=200; total time=   0.0s[CV] END ............................alpha=0.1, max_iter=200; total time=   0.0s
#
# [CV] END ............................alpha=0.1, max_iter=300; total time=   0.0s[CV] END ............................alpha=0.1, max_iter=200; total time=   0.0s
#
# [CV] END ............................alpha=0.1, max_iter=300; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=300; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=500; total time=   0.0s[CV] END ............................alpha=0.1, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=500; total time=   0.0s
#
# [CV] END ...........................alpha=0.01, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.1, max_iter=500; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=100; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=200; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=100; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=200; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=200; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=300; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=300; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=400; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=300; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=400; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=500; total time=   0.0s
# [CV] END ...........................alpha=0.01, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=300; total time=   0.0s[CV] END ...........................alpha=0.01, max_iter=500; total time=   0.0s
#
# [CV] END ...........................alpha=0.01, max_iter=500; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=300; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=200; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=100; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=300; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=200; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=500; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=400; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=500; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=500; total time=   0.0s
# [CV] END ............................alpha=0.5, max_iter=200; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=100; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=300; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=200; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=400; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=300; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=100; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=400; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=500; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=200; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=100; total time=   0.0s[CV] END ..........................alpha=0.001, max_iter=400; total time=   0.0s
#
# [CV] END ..........................alpha=0.001, max_iter=200; total time=   0.0s[CV] END ..........................alpha=0.001, max_iter=500; total time=   0.0s
#
# [CV] END ..........................alpha=0.001, max_iter=500; total time=   0.0s
# [CV] END ..........................alpha=0.001, max_iter=300; total time=   0.0s
# Fitting 3 folds for each of 200 candidates, totalling 600 fits
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=distance; total time=   0.0s[CV] END algorithm=auto, leaf_size=10, n_neighbors=9, weights=distance; total time=   0.0s
#
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=uniform; total time=   0.0s[CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform; total time=   0.0s
#
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=10, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance; total time=   0.0s[CV] END algorithm=auto, leaf_size=20, n_neighbors=3, weights=distance; total time=   0.0s
#
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=20, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=uniform; total time=   0.0s[CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=uniform; total time=   0.0s
#
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=30, n_neighbors=11, weights=distance; total time=   0.0s[CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=uniform; total time=   0.0s
#
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=7, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=40, n_neighbors=11, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=9, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=5, weights=distance; total time=   0.0s
# [CV] END algorithm=ball_tree, leaf_size=10, n_neighbors=9, weights=uniform; total time=   0.0s
# [CV] END algorithm=ball_tree, leaf_size=10, n_neighbors=3, weights=distance; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=7, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=11, weights=uniform; total time=   0.0s
# [CV] END algorithm=auto, leaf_size=50, n_neighbors=7, weights=uniform; total time=   0.0s
# ...
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.8; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.7; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.85; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.7; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.9; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.9; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.8; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.7; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=16, subsample=0.9; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.9; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.75; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.9; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.75; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.75; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.6; total time=   0.9s[CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.8; total time=   0.1s
#
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.6; total time=   0.3s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.8; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.85; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.6; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.8; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.6; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.85; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.7; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=32, subsample=0.9; total time=   0.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.6; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.85; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.7; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.75; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.7; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.75; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.75; total time=   0.3s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.8; total time=   0.3s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.8; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.8; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.85; total time=   0.8s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.6; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.85; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.85; total time=   0.3s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.85; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.9; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=64, subsample=0.9; total time=   0.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.7; total time=   1.2s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.6; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.6; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.9; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.6; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.7; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.7; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.9; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.6; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=8, subsample=0.7; total time=   0.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.7; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.7; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.75; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.75; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.75; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=sqrt, n_estimators=256, subsample=0.7; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.8; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.85; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.8; total time=   0.6s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.8; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.85; total time=   0.6s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.85; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.9; total time=   0.5s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.9; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=128, subsample=0.9; total time=   0.4s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.6; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.6; total time=   1.1s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.6; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.7; total time=   1.0s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.7; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.7; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.75; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.8; total time=   0.8s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.8; total time=   0.8s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.85; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.8; total time=   0.8s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.85; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.85; total time=   0.8s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.9; total time=   0.7s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.9; total time=   0.9s
# [CV] END criterion=friedman_mse, learning_rate=0.001, loss=quantile, max_features=log2, n_estimators=256, subsample=0.9; total time=   0.7s
# /home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 3456 fits failed out of a total of 10368.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1594 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of GradientBoostingRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 1862 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of GradientBoostingRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/ravi/insurence_prediction/in/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan ... -2.0660421  -2.0623831
#  -2.06130738]
#   warnings.warn(

# %%
result = pd.DataFrame([train_report,test_report]).T.reset_index()
result.columns = ["Regressor","train_score","test_score"]
result
# Out:
#                    Regressor  train_score  test_score
# 0          linear-regression     0.741730    0.783372
# 1           ridge-regression     0.741730    0.783360
# 2           lasso-regression     0.741730    0.783363
# 3             Knn-regression     0.998308    0.813938
# 4    Decision-tree-regressor     0.998308    0.655265
# 5    Random-forest-regressor     0.976495    0.860032
# 6          AdaBoostRegressor     0.858369    0.860196
# 7  GradientBoostingRegressor     0.867536    0.879397
